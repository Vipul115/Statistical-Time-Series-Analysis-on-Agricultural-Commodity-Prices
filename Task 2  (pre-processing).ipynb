# %% [markdown]
# ## 2. Understand price fluctuations accounting the seasonal effect

# %%
import pandas as pd
pd.set_option('chained_assignment',None)

# %%
df=pd.read_csv("Monthly_data_cmo_filtered.csv")
df["date"]=pd.to_datetime(df["date"])
df["quarter"]=df["date"].dt.quarter
df["combination_label"]=df["APMC"]+":"+df["Commodity"]
df.shape
# Out:
# (62225, 13)

# %%
# Grouping based on APMC, comm, year and taking count to remove those clusters with count<12
def group(df):
    data=df[["APMC","Commodity","modal_price","Year","combination_label"]].groupby(["APMC","Commodity","Year",
            "combination_label"],as_index=False).count().rename(columns={"modal_price":"Count"}).reset_index(drop=True)
    return data

# %% [markdown]
# ### Selecting only those APMC Commodities (cluster) which have data points for atleast a complete year (time series analysis)

# %%
data = group(df)
data = data[data['Count']==12].reset_index(drop=True)
data
# Out:
#                    APMC         Commodity  Year  \
# 0               Aamgaon    paddy-unhusked  2015
# 1         Akhadabalapur           soybean  2015
# 2                 Akluj      bitter gourd  2015
# 3                 Akluj           brinjal  2015
# 4                 Akluj           cabbage  2015
# 5                 Akluj            chikoo  2015
# 6                 Akluj     chillies(red)  2015
# 7                 Akluj            garlic  2015
# 8                 Akluj     ladies finger  2015
# 9                 Akluj             maize  2015
# 10                Akluj             onion  2015
# 11                Akluj            potato  2015
# 12                Akluj            shevga  2015
# 13                Akluj            tomato  2015
# 14                Akluj       water melon  2015
# 15                Akole             bajri  2015
# 16                Akole              gram  2015
# 17                Akole             onion  2015
# 18                Akole    paddy-unhusked  2015
# 19                Akole           soybean  2015
# 20                Akole     wheat(husked)  2015
# 21               Alibag   rice(paddy-hus)  2015
# 22            Amarawati        black gram  2015
# 23            Amarawati              gram  2015
# 24            Amarawati        green gram  2015
# 25            Amarawati  pigeon pea (tur)  2015
# 26            Amarawati     sorgum(jawar)  2015
# 27            Amarawati           soybean  2015
# 28            Amarawati     wheat(husked)  2015
# 29            Ambejogai              gram  2015
# ..                  ...               ...   ...
# 921               Vaduj              gram  2015
# 922               Vaduj             maize  2015
# 923               Vaduj     sorgum(jawar)  2015
# 924                 Vai      bottle gourd  2015
# 925                 Vai           brinjal  2015
# 926                 Vai           cabbage  2015
# 927                 Vai          cucumber  2015
# 928                 Vai            flower  2015
# 929                 Vai    ginger (fresh)  2015
# 930                 Vai      green chilli  2015
# 931                 Vai     ladies finger  2015
# 932                 Vai            pavata  2015
# 933                 Vai            tomato  2015
# 934  Varud-Rajura Bazar              gram  2015
# 935  Varud-Rajura Bazar     sorgum(jawar)  2015
# 936  Varud-Rajura Bazar           soybean  2015
# 937              Washim        black gram  2015
# 938              Washim              gram  2015
# 939              Washim        green gram  2015
# 940              Washim  pigeon pea (tur)  2015
# 941              Washim     sorgum(jawar)  2015
# 942              Washim           soybean  2015
# 943              Washim     wheat(husked)  2015
# 944               Yeola             bajri  2015
# 945               Yeola              gram  2015
# 946               Yeola             maize  2015
# 947               Yeola             onion  2015
# 948               Yeola     wheat(husked)  2015
# 949             Yeotmal  pigeon pea (tur)  2015
# 950             Yeotmal           soybean  2015
#
#                     combination_label  Count
# 0              Aamgaon:paddy-unhusked     12
# 1               Akhadabalapur:soybean     12
# 2                  Akluj:bitter gourd     12
# 3                       Akluj:brinjal     12
# 4                       Akluj:cabbage     12
# 5                        Akluj:chikoo     12
# 6                 Akluj:chillies(red)     12
# 7                        Akluj:garlic     12
# 8                 Akluj:ladies finger     12
# 9                         Akluj:maize     12
# 10                        Akluj:onion     12
# 11                       Akluj:potato     12
# 12                       Akluj:shevga     12
# 13                       Akluj:tomato     12
# 14                  Akluj:water melon     12
# 15                        Akole:bajri     12
# 16                         Akole:gram     12
# 17                        Akole:onion     12
# 18               Akole:paddy-unhusked     12
# 19                      Akole:soybean     12
# 20                Akole:wheat(husked)     12
# 21             Alibag:rice(paddy-hus)     12
# 22               Amarawati:black gram     12
# 23                     Amarawati:gram     12
# 24               Amarawati:green gram     12
# 25         Amarawati:pigeon pea (tur)     12
# 26            Amarawati:sorgum(jawar)     12
# 27                  Amarawati:soybean     12
# 28            Amarawati:wheat(husked)     12
# 29                     Ambejogai:gram     12
# ..                                ...    ...
# 921                        Vaduj:gram     12
# 922                       Vaduj:maize     12
# 923               Vaduj:sorgum(jawar)     12
# 924                  Vai:bottle gourd     12
# 925                       Vai:brinjal     12
# 926                       Vai:cabbage     12
# 927                      Vai:cucumber     12
# 928                        Vai:flower     12
# 929                Vai:ginger (fresh)     12
# 930                  Vai:green chilli     12
# 931                 Vai:ladies finger     12
# 932                        Vai:pavata     12
# 933                        Vai:tomato     12
# 934           Varud-Rajura Bazar:gram     12
# 935  Varud-Rajura Bazar:sorgum(jawar)     12
# 936        Varud-Rajura Bazar:soybean     12
# 937                 Washim:black gram     12
# 938                       Washim:gram     12
# 939                 Washim:green gram     12
# 940           Washim:pigeon pea (tur)     12
# 941              Washim:sorgum(jawar)     12
# 942                    Washim:soybean     12
# 943              Washim:wheat(husked)     12
# 944                       Yeola:bajri     12
# 945                        Yeola:gram     12
# 946                       Yeola:maize     12
# 947                       Yeola:onion     12
# 948               Yeola:wheat(husked)     12
# 949          Yeotmal:pigeon pea (tur)     12
# 950                   Yeotmal:soybean     12
#
# [951 rows x 5 columns]

# %%
filtered=data["combination_label"].unique().tolist()
df_filtered=df[df["combination_label"].isin(filtered)].reset_index(drop=True)

# %%
# Data ready to use
df_filtered.to_csv("seasonal_data_analysis.csv",index=False)
